# %% [markdown]
# Steps to create a Sharpening Filter in OpenCV without using built-in functions:

# %% [markdown]
# Step 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2

# %%
img = cv2.imread('image.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
